# %% [markdown]
# # **IMAGE ANALYSIS**
# ## **Practice 2.** Resizing.
#
# #### Created by: Bryan Israel Blancas Pérez.
#
# ##### ID: 2016630031
#
# ##### Group: 3CV7

# %% [markdown]
# # **Image resizing**
#
# Image interpolation occurs when you resize or distort your image from one pixel grid to another. Image resizing is necessary when you need to increase or decrease the total number of pixels, whereas remapping can occur when you are correcting for lens distortion or rotating an image. Zooming refers to increase the quantity of pixels, so that when you zoom an image, you will see more detail.
#
# Interpolation works by using known data to estimate values at unknown points. For this practice, I will use **linear interpolation**.
#
# ### **Linear Interpolation**
#
# It is a method to construct new data points within the range of a discrete set of known data points. Since this is a linear method, we use an straight line between two points previusly known. For a value x in the interval [x1,x2], the value y along the straight line is given from the next equation:
#
# <img src="teoricalImages/straightlineequation.png" alt="header" style="height:100px;">
#
# Where:
# <ul>
#     <li> ( x1 , y1 ) and ( x2 , y2 ) are known points</li>
#     <li> x is the value in the interval [ x1 , x2 ]</li>
#     <li> y is the unknown value</li>
# </ul>
#
# In the following image, you can see the graph of this method.
#
# <img src="teoricalImages/linearinterpolation.png" alt="header" style="height:220px;">
#
#
# ### **Resizing process**
#
# #### *Sampling*
#
# The algorithm starts with the sampling of an image, i.e. it's necessary to obtain the values of the image in order to make the process works. It's necessary to say that any digital image lost information in the sampling process, this is because computers are not able to have a continuos function. In computers we have always discrete functions.
#
# Let's suppose that we have and image which size is (5,5), and his matrix representation is the next:
#
# <img src="teoricalImages/matrixrepresentation.png" alt="header" style="height:220px;">
#
# Sampling the image means identify the tonal value per pixel. For this example I will sample the first row of the image in a graph.
#
# <img src="teoricalImages/firstrow.png" alt="header" style="width:600px;">
# <img src="teoricalImages/sampling.png" alt="header" style="width:600px;">
#
# Now we have sampling the first row, we need to define the new size of the first row, that also will be the new width of the entire image.
#
# #### *Defining the new size*
#
# Let's supose we want to resize the width to only 4 pixels. The process tell us that the first and the last point will remain in the same position of the sampling and the others will be between those two points. The next graph is helful to undertand this.
#
# <img src="teoricalImages/linearinterpolationexample.png" alt="header" style="width:600px;">
#
# The orange points are the new 4 pixels of the image. To put them in the correct position, we need to get the new ratio *a*, given by: originalSize / newSize. In this case a = 5/4 = 1.25
#
#
# #### *Linear interpolation*
#
# Now we use linear interpolation to calculate the new tonal value of each new pixel.
#
# <img src="teoricalImages/linearinterpolationexample.png" alt="header" style="width:600px;">
#
#
# **For pixel 1:**
#     <ul>
#     <li> X = no_pixel * a = 1 * 1.25 = 1.25</li>
#     <li> ( x1 , y1 ) is the nearest minor pixel, so ( x1 , y1 ) = ( 1 , 5 ) </li>
#     <li> ( x2 , y2 ) is the nearest major pixel, so ( x2 , y2 ) = ( 2 , 1 ) </li>
#     </ul>
# Now, let's use the linear interpolation to calculate the new tonal value:
# <img src="teoricalImages/valueforpixel1.png" alt="header" style="height:100px;">
#
# **For pixel 2:**
#     <ul>
#     <li> X = no_pixel * a = 2 * 1.25 = 2.5</li>
#     <li> ( x1 , y1 ) is the nearest minor pixel, so ( x1 , y1 ) = ( 2 , 1 ) </li>
#     <li> ( x2 , y2 ) is the nearest major pixel, so ( x2 , y2 ) = ( 3 , 2 ) </li>
#     </ul>
# Now, let's use the linear interpolation to calculate the new tonal value:
#
# <img src="teoricalImages/valueforpixel2.png" alt="header" style="height:100px;">
#
# At this point, we have the new first row, which size is equal to 4
#
# <img src="teoricalImages/newfirstrow.png" alt="header" style="width:600px;">
# <img src="teoricalImages/samplingnewfirstrow.png" alt="header" style="width:600px;">
#
#
# As we can see, linear interpolation gives us an approximation which means that lose of information is possible no matter if we are enlarging or shrinking the image.
#
# #### *Considerations*
#
# <ul>
#     <li> <b>New tonal value:</b> The new tonal value is equal to the nearest interger of the real value. If the new tonal value is 1.6, in the matrix will be 2, or if it's 1.3 in the matrix will be 1. This is because the nature of tonal values, there are no decimal tonal values.</li>
#     <li> <b>Resizing the complete image: </b> In the example above, I only show you the process for one row so in order to resizing the complete image you need to repeat the same process with all rows of the image and then with all columns to resize the height of the image</li>
#     <li> <b>Enlarging an image: </b> To enlarging an image the process is exactly the same that the one shown above, the only difference is that the number of points between the original one and the final one is bigger, so new ratio 'a' will be less than one.</li>
# </ul>
#
#
# In the cells bellow, I show you the implementation of resizing algorithm in python and optimized with cython. Each cell has an explanation of his behaviour.

# %% [markdown]
# **Load Cython extension**

# %%
# Load cython
# %load_ext Cython

# %% [markdown]
# **Implementation of nearest integer function**
#
# Due to the nature of the problem, this functions only works for positive values

# %%
# %%cython -a
# # Only works for positive values
# def nearest_integer(float i):
#     if( float(i-int(i)) >= 0.5 ):
#         return int(i)+1
#     return int(i)
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.12 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_b75d241ee7593a59447d0456f03dcaa1.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# ...

# %% [markdown]
# **Implementation of straight equation**
#
# Due to the nature of the problem, x2 - x1 is always equal to 1

# %%
# %%cython -a
# # y = (x-x1)( (y2-y1) / (x2-x1) ) + y1
# # For this algorithm x2-x1 = 1 always, so:
# # y = (x-x1)(y2-y1) + y1
# def line(float x, int x1, int y1, int x2, int y2):
#     cdef float f1 = x-x1
#     cdef int f2 = int(y2)-int(y1)
#     cdef float y = ( float(f1) * float(f2) ) + float(y1)
#     return y
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.12 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_eb9ccaefbc8c1b555c528fb294b0acb5.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# ...

# %% [markdown]
# **Auxiliar function to calculate the new ratio of the resizing**

# %%
# %%cython -a
# # Calculate ratio given by:
# # original_size:x -> new_size:x1
# # variable_a      ->        1
# def calculate_ratio(float x, int x1):
#     return x / float(x1)
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.12 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_c7105b5e93c31667c0fdcffe38394693.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# ...

# %% [markdown]
# **Implementation of the resizing method**
#
# The code contains comments for better understanding

# %%
# %%cython -a
# from __main__ import calculate_ratio
# from __main__ import line
# from __main__ import nearest_integer
# cimport numpy as np
#
# def resize_image(np.ndarray[np.npy_uint8, ndim=3] image_array, int new_height, int new_width):
#
#     # Get original size of image
#     cdef int height = image_array.shape[0]
#     cdef int width = image_array.shape[1]
#     cdef int channels = image_array.shape[2]
#
#     # Create a copy of the image
#     cdef np.ndarray resized_image = image_array.copy()
#
#     #####################
#     #	FOR NEW HEIGHT  #
#     #####################
#
#     # Resize the image with the new value of height
#     resized_image.resize(new_height, width, channels)
#
#     # Calculate new ratio
#     cdef a = calculate_ratio(height, new_height)
#     cdef char current_channel = 0
#     cdef int current_column = 0
#     cdef int current_row = 0
#     cdef int i = 1
#     cdef float x = 0
#     cdef int x1 = 0
#     cdef int y1 = 0
#     cdef int x2 = 0
#     cdef int y2 = 0
#     cdef int new_value = 0
#
#     # Traversal all channels, the whole width and the new height
#     for current_channel in range(3):
#         for current_column in range(width):
#             for i in range(1, new_height):
#
#                 # Current value of new pixel
#                 x = i * a
#
#                 # Values of nearest pixel to the left of X
#                 x1 = int(x)
#                 y1 = image_array[x1, current_column, current_channel]
#
#                 # Values of nearest pixel to the right of X
#                 x2 = x1 + 1
#                 if(x2 == height):
#                     x2 -= 1
#                 y2 = image_array[x2, current_column, current_channel]
#
#                 # Calculate new tonal value of new pixel i
#                 new_value = nearest_integer(line(x, x1, y1, x2, y2))
#
#                 # Assigment of new tonal value in the resized image
#                 resized_image[i, current_column, current_channel] = new_value
#
#     #####################
#     #	FOR NEW WIDTH   #
#     #####################
#
#     # Create a new array in order of set the new width
#     # Now resized_image, i.e. the image with a new height is our initial image
#     cdef np.ndarray resized_image2 = resized_image.copy()
#     resized_image2.resize(new_height, new_width, channels)
#
#     # Calculate new ratio
#     a = calculate_ratio(width, new_width)
#
#     #Traversal all channels, the whole width and the new width
#     for current_channel in range(3):
#         for current_row in range(new_height):
#             for i in range(1, new_width):
#
#                 # Current value of new pixel
#                 x = i * a
#
#                  # Values of nearest pixel to the left of X
#                 x1 = int(x)
#                 y1 = resized_image[current_row, x1, current_channel]
#
#                 # Values of nearest pixel to the right of X
#                 x2 = x1 + 1
#                 if(x2 == width):
#                     x2 -= 1
#                 y2 = resized_image[current_row, x2, current_channel]
#
#                  # Calculate new tonal value of new pixel i
#                 new_value = nearest_integer(line(x, x1, y1, x2, y2))
#
#                 # Assigment of new tonal value in the resized image
#                 resized_image2[current_row, i, current_channel] = new_value
#
#     # Return resized image
#     return resized_image2
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.12 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_0b939d0a0071f6d0aee8ce7f88e4abe5.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# ...

# %% [markdown]
# # **Rest of the code**
#
# Now, the rest of the code is shown in order. This section contains the integration of all the functions above as well as the libraries used. Also, the code contains the code lines necessary to show the process and the final result of the algorithm, i.e, theresized-image when the notebook is executed.

# %% [markdown]
# **1. Import <a href="https://numpy.org">NumPy</a>, <a href="https://matplotlib.org">matplotlib</a> and Image from <a href="https://pillow.readthedocs.io/en/stable/">PIL</a>**

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %% [markdown]
# **2. Open an image**

# %%
image_name = "./guitar.jpg"
image = Image.open(image_name)
image_array = np.asarray(image)

# %% [markdown]
# **3. Asking for the new width and height of the image**

# %%
print("Original size: "+str(image_array.shape))
new_height = int(input("New height: "))
new_width = int(input("New width: "))
# Out:
# Original size: (550, 269, 3)
# New height:  1100
# New width:  538

# %% [markdown]
# **4. Executing the resize image function**

# %%
# %time resized_image = resize_image(image_array, new_height, new_width)
# Out:
# CPU times: user 7.58 s, sys: 23.2 ms, total: 7.6 s
# Wall time: 7.58 s

# %% [markdown]
# **4. Showing the original image**

# %%
print("Original size: " + str(image_array.shape))
plt.imshow(image_array)
# Out:
# Original size: (550, 269, 3)

# %% [markdown]
# **5. Showing the resized image**

# %%
print("New size: " + str(resized_image.shape))
plt.imshow(resized_image)
# Out:
# New size: (1100, 538, 3)

# %% [markdown]
# # **Conclutions**
#
# This practice makes me see the complexity of resizing an image. Before this practice I had another idea about the resizing process. I thought that, for example, to enlarge an image it was only repeat as many pixels as necessary, but by doing this practice I realize the use of interpolation.
#
# Now, I know how to resize an image with linear interpolation, however, this is not the unique interpolation to do this. Others interpolation methods, such as bicubic and splines, can be used to resize an image. It's said that those methods are slower that linear interpolation but more accurate.
#
# As I was doing the code I had few problems mainly with the resize of the new image. I realized that it was not a good idea resize height and width at the same time because many problems would appear by the end of the process, instead of that, I decided to resize firstly the height and after finished that part of the algorithm I would take the new image with the new height as a new original image, which would only need to resize the width.
#
# In my first version of the code I saw that it was really slow so I decided to optimize it. After some corrections I was able to use Cython to make the fastest version of the code. Version which is shown above in the notebook. Resizing an image that previously took 1 minute and 12 seconds, after implement Cython can be done in only 11 seconds.
